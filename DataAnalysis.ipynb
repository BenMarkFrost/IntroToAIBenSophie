# %%
# for i in range(2):
#     print("Attempt " + str(i+1))
#     try:
#         import os
#         import cv2
#         import numpy as np
#         import sklearn as sk
#         import tqdm
#         import matplotlib.pyplot as plt
#         print("Library imports successful")
#         break
#     except:
#         print("Attempting library installs")
#         !pip install opencv-python
#         !pip install numpy
#         !pip install sklearn

import os
import cv2
import numpy as np
import sklearn as sk
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
import sklearn

# %%
categories = {'Apple':"Apple/Apple A/", "Banana":"Banana/"}
dataDirectory = "../../Data/archive/"
apples = "Apple/Apple A/"

# %%
img_apple = cv2.imread(dataDirectory + apples + "Apple 1.png")

def show(img):
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img)

show(img_apple)

# %%
def createTrainingSet(categories):
    
    trainingData = []
    
    for fruitCategory in categories:
        
        path = dataDirectory + categories.get(fruitCategory)
        
        for img in tqdm(os.listdir(path)):
            
            try:
                
                img_array = cv2.imread(path + img)
                resized_array = cv2.resize(img_array, (480, 322))
                trainingData.append([resized_array, fruitCategory])
                
            except:
                
                print("Could not find " + path + img)
    
    return trainingData

# %%
trainingData = createTrainingSet(categories)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 692/692 [00:02<00:00, 323.88it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 3027/3027 [00:07<00:00, 396.01it/s]

# %%
trainingData[len(trainingData)-1]
# Out:
# [array([[[ 67,  65,  59],
#          [ 61,  59,  53],
#          [ 56,  53,  47],
#          ...,
#          [147, 131, 113],
#          [141, 124, 106],
#          [137, 119, 102]],
#
#         [[ 62,  61,  55],
#          [ 60,  60,  54],
#          [ 59,  57,  52],
#          ...,
#          [151, 134, 116],
#          [149, 131, 114],
#          [147, 130, 112]],
#
#         [[ 59,  59,  56],
#          [ 58,  58,  55],
#          [ 58,  56,  53],
#          ...,
#          [151, 135, 118],
#          [150, 134, 116],
#          [149, 132, 115]],
#
#         ...,
#
#         [[121, 102,  92],
#          [122, 102,  93],
#          [123, 103,  94],
#          ...,
#          [ 64,  63,  66],
#          [ 63,  63,  65],
#          [ 63,  63,  65]],
#
#         [[120, 100,  91],
#          [121, 102,  92],
#          [123, 103,  94],
#          ...,
#          [ 80,  78,  81],
#          [ 80,  79,  81],
#          [ 81,  79,  81]],
#
#         [[122, 102,  93],
#          [122, 102,  93],
#          [123, 104,  94],
#          ...,
#          [ 99,  97, 100],
#          [100,  99, 101],
#          [101, 100, 102]]], dtype=uint8),
#  'Banana']

# %%
show(trainingData[0][0])
